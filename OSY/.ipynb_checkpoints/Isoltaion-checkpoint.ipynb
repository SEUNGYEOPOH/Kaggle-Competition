# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials
import seaborn as sns
from sklearn.model_selection import StratifiedKFold

# %%
def reduce_mem(df: pd.DataFrame):
    "This method reduces memory for numeric columns in the dataframe";

    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64', "uint16", "uint32", "uint64"];
    start_mem = df.memory_usage().sum() / 1024**2;

    for col in df.columns:
        col_type = df[col].dtypes

        if col_type in numerics:
            c_min = df[col].min();
            c_max = df[col].max();

            if "int" in str(col_type):
                if c_min >= np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min >= np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min >= np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min >= np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min >= np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                if c_min >= np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)  

    end_mem = df.memory_usage().sum() / 1024**2

    print(f"Start - end memory:- {start_mem:5.2f} - {end_mem:5.2f} Mb");
    return df;

# %%
train = pd.read_csv("./playground-series-s4e7/train.csv")
target = pd.read_csv("./playground-series-s4e7/test.csv")

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11504798 entries, 0 to 11504797
# Data columns (total 12 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id                    int64
#  1   Gender                object
#  2   Age                   int64
#  3   Driving_License       int64
#  4   Region_Code           float64
#  5   Previously_Insured    int64
#  6   Vehicle_Age           object
#  7   Vehicle_Damage        object
#  8   Annual_Premium        float64
#  9   Policy_Sales_Channel  float64
#  10  Vintage               int64
#  11  Response              int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 1.0+ GB

# %%
train = train.drop(columns=["id"], axis=1)

# %%
target= target.drop(columns=["id"], axis=1)

# %%
category_columns = train.select_dtypes(include="object").columns
category_columns = category_columns.tolist()

def label_encoding(df):
    # Instance of LabelEncoder
    label_encoders = {col: LabelEncoder() for col in category_columns}

    # Label Encoding
    for col in category_columns:
    
        df[col] = label_encoders[col].fit_transform(df[col])

label_encoding(train)

# %%
category_columns = target.select_dtypes(include="object").columns
category_columns = category_columns.tolist()
def label_encoding(df):
    # Instance of LabelEncoder
    label_encoders = {col: LabelEncoder() for col in category_columns}

    # Label Encoding
    for col in category_columns:
    
        df[col] = label_encoders[col].fit_transform(df[col])
label_encoding(target)

# %%
train
# Out:
#           Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0              1   21                1         35.0                   0
# 1              1   43                1         28.0                   0
# 2              0   25                1         14.0                   1
# 3              0   35                1          1.0                   0
# 4              0   36                1         15.0                   1
# ...          ...  ...              ...          ...                 ...
# 11504793       1   48                1          6.0                   0
# 11504794       0   26                1         36.0                   0
# 11504795       0   29                1         32.0                   1
# 11504796       0   51                1         28.0                   0
# 11504797       1   25                1         28.0                   1
#
#           Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 0                   0               1         65101.0                 124.0
# 1                   2               1         58911.0                  26.0
# 2                   1               0         38043.0                 152.0
# 3                   0               1          2630.0                 156.0
# 4                   0               0         31951.0                 152.0
# ...               ...             ...             ...                   ...
# 11504793            0               1         27412.0                  26.0
# 11504794            1               1         29509.0                 152.0
# 11504795            1               0          2630.0                 152.0
# 11504796            0               1         48443.0                  26.0
# 11504797            1               0         32855.0                 152.0
#
#           Vintage  Response
# 0             187         0
# 1             288         1
# 2             254         0
# 3              76         0
# 4             294         0
# ...           ...       ...
# 11504793      218         0
# 11504794      115         1
# 11504795      189         0
# 11504796      274         1
# 11504797      189         0
#
# [11504798 rows x 11 columns]

# %%
target
# Out:
#          Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0             0   20                1         47.0                   0
# 1             1   47                1         28.0                   0
# 2             1   47                1         43.0                   0
# 3             0   22                1         47.0                   1
# 4             1   51                1         19.0                   0
# ...         ...  ...              ...          ...                 ...
# 7669861       1   57                1         28.0                   0
# 7669862       1   28                1         50.0                   1
# 7669863       1   47                1         33.0                   1
# 7669864       1   30                1         28.0                   0
# 7669865       1   23                1         46.0                   1
#
#          Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 0                  1               0          2630.0                 160.0
# 1                  0               1         37483.0                 124.0
# 2                  0               1          2630.0                  26.0
# 3                  1               0         24502.0                 152.0
# 4                  0               0         34115.0                 124.0
# ...              ...             ...             ...                   ...
# 7669861            0               1         51661.0                 124.0
# 7669862            1               0         25651.0                 152.0
# 7669863            0               0          2630.0                 138.0
# 7669864            1               1         38866.0                 124.0
# 7669865            1               0         27498.0                 152.0
#
#          Vintage
# 0            228
# 1            123
# 2            271
# 3            115
# 4            148
# ...          ...
# 7669861      109
# 7669862      184
# 7669863       63
# 7669864      119
# 7669865       79
#
# [7669866 rows x 10 columns]

# %%
train = reduce_mem(train)
# Out:
# Start - end memory:- 833.86 - 230.41 Mb

# %%
target = reduce_mem(target)
# Out:
# Start - end memory:- 497.39 - 146.29 Mb

# %%
b=train['Response'][train['Response']==1].count()

# %%
a=train['Response'][train['Response']==0].count()

# %%
b/len(train)
# Out:
# 0.12299729208631043

# %%
a/len(train)
# Out:
# 0.8770027079136896

# %%
train.isna().sum()
# Out:
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
train.describe()
# Out:
#             Gender          Age  Driving_License  Region_Code  \
# count 11504798.000 11504798.000     11504798.000 11504798.000
# mean         0.541       38.384            0.998       26.419
# std          0.498       14.993            0.044       12.992
# min          0.000       20.000            0.000        0.000
# 25%          0.000       24.000            1.000       15.000
# 50%          1.000       36.000            1.000       28.000
# 75%          1.000       49.000            1.000       35.000
# max          1.000       85.000            1.000       52.000
#
#        Previously_Insured  Vehicle_Age  Vehicle_Damage  Annual_Premium  \
# count        11504798.000 11504798.000    11504798.000    11504798.000
# mean                0.463        0.522           0.503       30461.359
# std                 0.499        0.577           0.500       16454.744
# min                 0.000        0.000           0.000        2630.000
# 25%                 0.000        0.000           0.000       25277.000
# 50%                 0.000        0.000           1.000       31824.000
# 75%                 1.000        1.000           1.000       39451.000
# max                 1.000        2.000           1.000      540165.000
#
#        Policy_Sales_Channel      Vintage     Response
# count          11504798.000 11504798.000 11504798.000
# mean                112.425      163.898        0.123
# std                  54.036       79.980        0.328
# min                   1.000       10.000        0.000
# 25%                  29.000       99.000        0.000
# 50%                 151.000      166.000        0.000
# 75%                 152.000      232.000        0.000
# max                 163.000      299.000        1.000

# %%
df = train.copy()
x= df.drop(columns=['Response'],axis=1)
y= df['Response']

# %%
x_train, x_val, y_train, y_val = train_test_split(x,y,test_size=0.2,random_state=0,stratify=y)

# %%
from sklearn.ensemble import IsolationForest
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score
from sklearn.metrics import f1_score, confusion_matrix, precision_recall_curve, roc_curve

# %%
iso_forest = IsolationForest(contamination=0.2, random_state=42)
iso_forest.fit(x_train)
# Out:
# C:\Users\OSY\anaconda3\envs\osy\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# IsolationForest(contamination=0.2, random_state=42)

# %%
anomaly_scores = -iso_forest.decision_function(x_val)

# %%
roc_auc = roc_auc_score(y_val, anomaly_scores)
print(roc_auc)
# Out:
# 0.459548840781502

# %%
a=-iso_forest.decision_function(target)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_39836\3792639753.py in <cell line: 1>()
# ----> 1 a=-iso_forest.decision_function(target)
#
# ~\anaconda3\envs\osy\lib\site-packages\sklearn\ensemble\_iforest.py in decision_function(self, X)
#     392         # an outlier:
#     393
# --> 394         return self.score_samples(X) - self.offset_
#     395
#     396     def score_samples(self, X):
#
# ~\anaconda3\envs\osy\lib\site-packages\sklearn\ensemble\_iforest.py in score_samples(self, X)
#     427         # Take the opposite of the scores as bigger is better (here less
#     428         # abnormal)
# --> 429         return -self._compute_chunked_score_samples(X)
#     430
#     431     def _compute_chunked_score_samples(self, X):
#
# ~\anaconda3\envs\osy\lib\site-packages\sklearn\ensemble\_iforest.py in _compute_chunked_score_samples(self, X)
#     458         for sl in slices:
#     459             # compute score on the slices of test samples:
# --> 460             scores[sl] = self._compute_score_samples(X[sl], subsample_features)
#     461
#     462         return scores
#
# ~\anaconda3\envs\osy\lib\site-packages\sklearn\ensemble\_iforest.py in _compute_score_samples(self, X, subsample_features)
#     481             X_subset = X[:, features] if subsample_features else X
#     482
# --> 483             leaves_index = tree.apply(X_subset)
#     484             node_indicator = tree.decision_path(X_subset)
#     485             n_samples_leaf = tree.tree_.n_node_samples[leaves_index]
#
# ~\anaconda3\envs\osy\lib\site-packages\sklearn\tree\_classes.py in apply(self, X, check_input)
#     476         """
#     477         check_is_fitted(self)
# --> 478         X = self._validate_X_predict(X, check_input)
#     479         return self.tree_.apply(X)
#     480
#
# ~\anaconda3\envs\osy\lib\site-packages\sklearn\tree\_classes.py in _validate_X_predict(self, X, check_input)
#     390         """Validate the training data on predict (probabilities)."""
#     391         if check_input:
# --> 392             X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     393             if issparse(X) and (
#     394                 X.indices.dtype != np.intc or X.indptr.dtype != np.intc
#
# ~\anaconda3\envs\osy\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     563             raise ValueError("Validation should be done on X, y or both.")
#     564         elif not no_val_X and no_val_y:
# --> 565             X = check_array(X, input_name="X", **check_params)
#     566             out = X
#     567         elif no_val_X and not no_val_y:
#
# ~\anaconda3\envs\osy\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     919
#     920         if force_all_finite:
# --> 921             _assert_all_finite(
#     922                 array,
#     923                 input_name=input_name,
#
# ~\anaconda3\envs\osy\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     120     # error message.
#     121     with np.errstate(over="ignore"):
# --> 122         first_pass_isfinite = xp.isfinite(xp.sum(X))
#     123     if first_pass_isfinite:
#     124         return
#
# ~\anaconda3\envs\osy\lib\site-packages\numpy\core\overrides.py in sum(*args, **kwargs)
#
# ~\anaconda3\envs\osy\lib\site-packages\numpy\core\fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial, where)
#    2322         return res
#    2323
# -> 2324     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2325                           initial=initial, where=where)
#    2326
#
# ~\anaconda3\envs\osy\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# KeyboardInterrupt:

# %%
submit = pd.read_csv("./playground-series-s4e7/sample_submission.csv")
pred = a 
submit["Response"] = pred
submit.to_csv("submission_isolation.csv", index=False)
submit.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_39836\3327746228.py in <cell line: 1>()
# ----> 1 submit = pd.read_csv("./playground-series-s4e7/sample_submission.csv")
#       2 pred = a
#       3 submit["Response"] = pred
#       4 submit.to_csv("submission_isolation.csv", index=False)
#       5 submit.head()
#
# ~\anaconda3\envs\osy\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ~\anaconda3\envs\osy\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ~\anaconda3\envs\osy\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# ~\anaconda3\envs\osy\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     609
#     610     with parser:
# --> 611         return parser.read(nrows)
#     612
#     613
#
# ~\anaconda3\envs\osy\lib\site-packages\pandas\io\parsers\readers.py in read(self, nrows)
#    1776                     columns,
#    1777                     col_dict,
# -> 1778                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1779                     nrows
#    1780                 )
#
# ~\anaconda3\envs\osy\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in read(self, nrows)
#     228         try:
#     229             if self.low_memory:
# --> 230                 chunks = self._reader.read_low_memory(nrows)
#     231                 # destructive to chunks
#     232                 data = _concatenate_chunks(chunks)
#
# ~\anaconda3\envs\osy\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# ~\anaconda3\envs\osy\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# ~\anaconda3\envs\osy\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# ~\anaconda3\envs\osy\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.
