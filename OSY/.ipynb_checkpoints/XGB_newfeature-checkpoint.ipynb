# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials
import seaborn as sns
from sklearn.model_selection import StratifiedKFold

# %%
def reduce_mem(df: pd.DataFrame):
    "This method reduces memory for numeric columns in the dataframe";

    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64', "uint16", "uint32", "uint64"];
    start_mem = df.memory_usage().sum() / 1024**2;

    for col in df.columns:
        col_type = df[col].dtypes

        if col_type in numerics:
            c_min = df[col].min();
            c_max = df[col].max();

            if "int" in str(col_type):
                if c_min >= np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min >= np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min >= np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min >= np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min >= np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                if c_min >= np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)  

    end_mem = df.memory_usage().sum() / 1024**2

    print(f"Start - end memory:- {start_mem:5.2f} - {end_mem:5.2f} Mb");
    return df;

# %%
train = pd.read_csv("./playground-series-s4e7/train.csv")
target = pd.read_csv("./playground-series-s4e7/test.csv")

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11504798 entries, 0 to 11504797
# Data columns (total 12 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id                    int64
#  1   Gender                object
#  2   Age                   int64
#  3   Driving_License       int64
#  4   Region_Code           float64
#  5   Previously_Insured    int64
#  6   Vehicle_Age           object
#  7   Vehicle_Damage        object
#  8   Annual_Premium        float64
#  9   Policy_Sales_Channel  float64
#  10  Vintage               int64
#  11  Response              int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 1.0+ GB

# %%
train = train.drop(columns=["id"], axis=1)

# %%
target= target.drop(columns=["id"], axis=1)

# %%
category_columns = train.select_dtypes(include="object").columns
category_columns = category_columns.tolist()

def label_encoding(df):
    # Instance of LabelEncoder
    label_encoders = {col: LabelEncoder() for col in category_columns}

    # Label Encoding
    for col in category_columns:
    
        df[col] = label_encoders[col].fit_transform(df[col])

label_encoding(train)

# %%
category_columns = target.select_dtypes(include="object").columns
category_columns = category_columns.tolist()
def label_encoding(df):
    # Instance of LabelEncoder
    label_encoders = {col: LabelEncoder() for col in category_columns}

    # Label Encoding
    for col in category_columns:
    
        df[col] = label_encoders[col].fit_transform(df[col])
label_encoding(target)

# %%
train
# Out:
#           Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0              1   21                1       35.000                   0
# 1              1   43                1       28.000                   0
# 2              0   25                1       14.000                   1
# 3              0   35                1        1.000                   0
# 4              0   36                1       15.000                   1
# ...          ...  ...              ...          ...                 ...
# 11504793       1   48                1        6.000                   0
# 11504794       0   26                1       36.000                   0
# 11504795       0   29                1       32.000                   1
# 11504796       0   51                1       28.000                   0
# 11504797       1   25                1       28.000                   1
#
#           Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 0                   0               1       65101.000               124.000
# 1                   2               1       58911.000                26.000
# 2                   1               0       38043.000               152.000
# 3                   0               1        2630.000               156.000
# 4                   0               0       31951.000               152.000
# ...               ...             ...             ...                   ...
# 11504793            0               1       27412.000                26.000
# 11504794            1               1       29509.000               152.000
# 11504795            1               0        2630.000               152.000
# 11504796            0               1       48443.000                26.000
# 11504797            1               0       32855.000               152.000
#
#           Vintage  Response
# 0             187         0
# 1             288         1
# 2             254         0
# 3              76         0
# 4             294         0
# ...           ...       ...
# 11504793      218         0
# 11504794      115         1
# 11504795      189         0
# 11504796      274         1
# 11504797      189         0
#
# [11504798 rows x 11 columns]

# %%
target
# Out:
#          Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0             0   20                1         47.0                   0
# 1             1   47                1         28.0                   0
# 2             1   47                1         43.0                   0
# 3             0   22                1         47.0                   1
# 4             1   51                1         19.0                   0
# ...         ...  ...              ...          ...                 ...
# 7669861       1   57                1         28.0                   0
# 7669862       1   28                1         50.0                   1
# 7669863       1   47                1         33.0                   1
# 7669864       1   30                1         28.0                   0
# 7669865       1   23                1         46.0                   1
#
#          Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 0                  1               0          2630.0                 160.0
# 1                  0               1         37483.0                 124.0
# 2                  0               1          2630.0                  26.0
# 3                  1               0         24502.0                 152.0
# 4                  0               0         34115.0                 124.0
# ...              ...             ...             ...                   ...
# 7669861            0               1         51661.0                 124.0
# 7669862            1               0         25651.0                 152.0
# 7669863            0               0          2630.0                 138.0
# 7669864            1               1         38866.0                 124.0
# 7669865            1               0         27498.0                 152.0
#
#          Vintage
# 0            228
# 1            123
# 2            271
# 3            115
# 4            148
# ...          ...
# 7669861      109
# 7669862      184
# 7669863       63
# 7669864      119
# 7669865       79
#
# [7669866 rows x 10 columns]

# %%
train = reduce_mem(train)
# Out:
# Start - end memory:- 833.86 - 230.41 Mb

# %%
target = reduce_mem(target)
# Out:
# Start - end memory:- 497.39 - 146.29 Mb

# %%
target
# Out:
#          Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0             0   20                1         47.0                   0
# 1             1   47                1         28.0                   0
# 2             1   47                1         43.0                   0
# 3             0   22                1         47.0                   1
# 4             1   51                1         19.0                   0
# ...         ...  ...              ...          ...                 ...
# 7669861       1   57                1         28.0                   0
# 7669862       1   28                1         50.0                   1
# 7669863       1   47                1         33.0                   1
# 7669864       1   30                1         28.0                   0
# 7669865       1   23                1         46.0                   1
#
#          Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 0                  1               0          2630.0                 160.0
# 1                  0               1         37483.0                 124.0
# 2                  0               1          2630.0                  26.0
# 3                  1               0         24502.0                 152.0
# 4                  0               0         34115.0                 124.0
# ...              ...             ...             ...                   ...
# 7669861            0               1         51661.0                 124.0
# 7669862            1               0         25651.0                 152.0
# 7669863            0               0          2630.0                 138.0
# 7669864            1               1         38866.0                 124.0
# 7669865            1               0         27498.0                 152.0
#
#          Vintage
# 0            228
# 1            123
# 2            271
# 3            115
# 4            148
# ...          ...
# 7669861      109
# 7669862      184
# 7669863       63
# 7669864      119
# 7669865       79
#
# [7669866 rows x 10 columns]

# %%
b=train['Response'][train['Response']==1].count()

# %%
a=train['Response'][train['Response']==0].count()

# %%
b/len(train)
# Out:
# 0.12299729208631043

# %%
a/len(train)
# Out:
# 0.8770027079136896

# %%
train.isna().sum()
# Out:
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
train.describe()
# Out:
#             Gender          Age  Driving_License  Region_Code  \
# count 11504798.000 11504798.000     11504798.000 11504798.000
# mean         0.541       38.384            0.998       26.419
# std          0.498       14.993            0.044       12.992
# min          0.000       20.000            0.000        0.000
# 25%          0.000       24.000            1.000       15.000
# 50%          1.000       36.000            1.000       28.000
# 75%          1.000       49.000            1.000       35.000
# max          1.000       85.000            1.000       52.000
#
#        Previously_Insured  Vehicle_Age  Vehicle_Damage  Annual_Premium  \
# count        11504798.000 11504798.000    11504798.000    11504798.000
# mean                0.463        0.522           0.503       30461.359
# std                 0.499        0.577           0.500       16454.744
# min                 0.000        0.000           0.000        2630.000
# 25%                 0.000        0.000           0.000       25277.000
# 50%                 0.000        0.000           1.000       31824.000
# 75%                 1.000        1.000           1.000       39451.000
# max                 1.000        2.000           1.000      540165.000
#
#        Policy_Sales_Channel      Vintage     Response
# count          11504798.000 11504798.000 11504798.000
# mean                112.425      163.898        0.123
# std                  54.036       79.980        0.328
# min                   1.000       10.000        0.000
# 25%                  29.000       99.000        0.000
# 50%                 151.000      166.000        0.000
# 75%                 152.000      232.000        0.000
# max                 163.000      299.000        1.000

# %%
train
# Out:
#           Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0              1   21                1       35.000                   0
# 1              1   43                1       28.000                   0
# 2              0   25                1       14.000                   1
# 3              0   35                1        1.000                   0
# 4              0   36                1       15.000                   1
# ...          ...  ...              ...          ...                 ...
# 11504793       1   48                1        6.000                   0
# 11504794       0   26                1       36.000                   0
# 11504795       0   29                1       32.000                   1
# 11504796       0   51                1       28.000                   0
# 11504797       1   25                1       28.000                   1
#
#           Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 0                   0               1       65101.000               124.000
# 1                   2               1       58911.000                26.000
# 2                   1               0       38043.000               152.000
# 3                   0               1        2630.000               156.000
# 4                   0               0       31951.000               152.000
# ...               ...             ...             ...                   ...
# 11504793            0               1       27412.000                26.000
# 11504794            1               1       29509.000               152.000
# 11504795            1               0        2630.000               152.000
# 11504796            0               1       48443.000                26.000
# 11504797            1               0       32855.000               152.000
#
#           Vintage  Response
# 0             187         0
# 1             288         1
# 2             254         0
# 3              76         0
# 4             294         0
# ...           ...       ...
# 11504793      218         0
# 11504794      115         1
# 11504795      189         0
# 11504796      274         1
# 11504797      189         0
#
# [11504798 rows x 11 columns]

# %%
import polars as pl

# %%
train = pl.from_pandas(train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_37948\3967956233.py in <cell line: 1>()
# ----> 1 train = pl.from_pandas(train)
#       2 target = pl.from_pandas(target)
#
# ~\anaconda3\envs\osy\lib\site-packages\polars\convert\general.py in from_pandas(data, schema_overrides, rechunk, nan_to_null, include_index)
#     578     else:
#     579         msg = f"expected pandas DataFrame or Series, got {type(data).__name__!r}"
# --> 580         raise TypeError(msg)
#     581
#     582
#
# TypeError: expected pandas DataFrame or Series, got 'DataFrame'

# %%
target = pl.from_pandas(target)

# %%
target = target.with_columns(pl.lit(0).cast(pl.Int64).alias('Response'))

# %%
tra

# %%
df = pl.concat([train, target])
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_37948\1226100002.py in <cell line: 1>()
# ----> 1 df = pl.concat([train, target])
#
# ~\anaconda3\envs\osy\lib\site-packages\polars\functions\eager.py in concat(items, how, rechunk, parallel)
#     180     if isinstance(first, pl.DataFrame):
#     181         if how == "vertical":
# --> 182             out = wrap_df(plr.concat_df(elems))
#     183         elif how == "vertical_relaxed":
#     184             out = wrap_ldf(
#
# SchemaError: type Int64 is incompatible with expected type Int8

# %%
df = df.with_columns([
    pl.col('Gender').replace({'Male': 0, 'Female': 1}).cast(pl.Int32),
    pl.col('Region_Code').cast(int),
    pl.col('Vehicle_Age').replace({'< 1 Year': 0, '1-2 Year': 1, '> 2 Years': 2}).cast(pl.Int32),
    pl.col('Vehicle_Damage').replace({'No': 0, 'Yes': 1}).cast(pl.Int32),
    pl.col('Annual_Premium').cast(int),
    pl.col('Policy_Sales_Channel').cast(int)
])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_37948\3937828868.py in <cell line: 1>()
# ----> 1 df = df.with_columns([
#       2     pl.col('Gender').replace({'Male': 0, 'Female': 1}).cast(pl.Int32),
#       3     pl.col('Region_Code').cast(int),
#       4     pl.col('Vehicle_Age').replace({'< 1 Year': 0, '1-2 Year': 1, '> 2 Years': 2}).cast(pl.Int32),
#       5     pl.col('Vehicle_Damage').replace({'No': 0, 'Yes': 1}).cast(pl.Int32),
#
# ~\anaconda3\envs\osy\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'with_columns'

# %%
df = train.copy()
x= df.drop(columns=['Response'],axis=1)
y= df['Response']

# %%
x_train, x_val, y_train, y_val = train_test_split(x,y,test_size=0.1,random_state=0,stratify=y)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score
from sklearn.metrics import f1_score, confusion_matrix, precision_recall_curve, roc_curve
from lightgbm import LGBMClassifier

# %%
def get_clf_eval(y_test, y_pred=None, pred_proba=None):
    confusion = confusion_matrix(y_test,y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    F1 = f1_score(y_test, y_pred)
    AUC = roc_auc_score(y_test, pred_proba)
    AU2 = roc_auc_score(y_test, y_pred.astype('float32'))
    
    print('\n정확도: {:.4f}'.format(accuracy))
    print('정밀도: {:.4f}'.format(precision))
    print('재현율: {:.4f}'.format(recall))
    print('F1: {:.4f}'.format(F1))
    print('AUC: {:.4f}'.format(AUC))
    print('AUC2 : {:.4f}'.format(AU2))

# %%
x_train
# Out:
#           Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 5853872        0   25                1       29.000                   1
# 4394468        1   25                1       47.000                   1
# 10202146       0   64                1       28.000                   0
# 4141629        1   22                1        8.000                   1
# 10688668       0   45                1       35.000                   0
# ...          ...  ...              ...          ...                 ...
# 5010815        1   52                0       28.000                   1
# 3679955        0   24                1       18.000                   0
# 10562844       1   58                1       39.000                   1
# 10500569       1   62                1       28.000                   1
# 3678888        0   74                1       28.000                   0
#
#           Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 5853872             1               0       27605.000               152.000
# 4394468             1               0       45282.000               152.000
# 10202146            2               1       34608.000                26.000
# 4141629             1               0       50398.000               152.000
# 10688668            0               1       27670.000               124.000
# ...               ...             ...             ...                   ...
# 5010815             0               0       55125.000                26.000
# 3679955             1               1       28103.000               152.000
# 10562844            0               0        2630.000                26.000
# 10500569            0               1       36177.000                26.000
# 3678888             2               1       46308.000               122.000
#
#           Vintage
# 5853872       171
# 4394468       177
# 10202146      251
# 4141629       216
# 10688668      119
# ...           ...
# 5010815        79
# 3679955       212
# 10562844       63
# 10500569      111
# 3678888        28
#
# [10354318 rows x 10 columns]

# %%
y_train
# Out:
# 5853872     0
# 4394468     0
# 10202146    1
# 4141629     0
# 10688668    1
#            ..
# 5010815     0
# 3679955     0
# 10562844    0
# 10500569    0
# 3678888     0
# Name: Response, Length: 10354318, dtype: int8

# %%
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
import numpy as np
from hyperopt import STATUS_OK

def objective(params):
    xgb_clf = XGBClassifier(
        n_estimators=int(params['n_estimators']),
        max_depth=int(params['max_depth']),
        learning_rate=params['learning_rate'],
        subsample=params['subsample'],
        colsample_bytree=params['colsample_bytree'],
        scale_pos_weight=params['scale_pos_weight'],
        min_child_weight=int(params['min_child_weight']),
        use_label_encoder=False,
        n_jobs=-1,
        eval_metric='auc',
        early_stopping_rounds = int(params['early_stopping_rounds']),
        verbosity=1
    )

    
    skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
    roc_auc_scores = []

    for train_idx, val_idx in skf.split(x_train, y_train):
        X_fold_train, X_fold_val = x_train.iloc[train_idx], x_train.iloc[val_idx]
        y_fold_train, y_fold_val = y_train.iloc[train_idx], y_train.iloc[val_idx]
        
        xgb_clf.fit(X_fold_train, y_fold_train, eval_set=[(X_fold_val, y_fold_val)], verbose=True)
        y_pred_proba = xgb_clf.predict_proba(X_fold_val)[:, 1]  # 클래스 확률 예측
        roc_auc = roc_auc_score(y_fold_val, y_pred_proba, multi_class='ovr')  # 다중 클래스 지원
        roc_auc_scores.append(roc_auc)
    
    mean_auc = np.mean(roc_auc_scores)
    return {'loss': -mean_auc, 'status': STATUS_OK}

# %%
space = {
    'n_estimators': hp.quniform('n_estimators', 30, 1000, 1),
    'max_depth': hp.quniform('max_depth', 5, 10, 1),
    'learning_rate': hp.loguniform('learning_rate', np.log(0.01), np.log(0.3)),
    'min_child_weight': hp.quniform('min_child_weight', 1, 10, 1), 
    'subsample': hp.uniform('subsample', 0.5, 1.0),  
    'colsample_bytree': hp.uniform('colsample_bytree', 0.5, 1.0),  
    'scale_pos_weight': hp.uniform('scale_pos_weight', 4, 15),
    'early_stopping_rounds' : 20
}

# %%
trials = Trials()
best = fmin(fn=objective, space=space, algo=tpe.suggest, max_evals=25, trials=trials, rstate=np.random.default_rng(42))
# Out:
#   0%|                                                                           | 0/25 [00:00<?, ?trial/s, best loss=?]
# C:\Users\OSY\anaconda3\envs\osy\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [0]	validation_0-auc:0.83503
# [1]	validation_0-auc:0.85872
# [2]	validation_0-auc:0.86025
# [3]	validation_0-auc:0.86066
# [4]	validation_0-auc:0.86100
# [5]	validation_0-auc:0.86099
# [6]	validation_0-auc:0.86141
# [7]	validation_0-auc:0.86182
# [8]	validation_0-auc:0.86185
# [9]	validation_0-auc:0.86224
# [10]	validation_0-auc:0.86224
# [11]	validation_0-auc:0.86214
# [12]	validation_0-auc:0.86268
# [13]	validation_0-auc:0.86265
# [14]	validation_0-auc:0.86300
# [15]	validation_0-auc:0.86307
# [16]	validation_0-auc:0.86313
# [17]	validation_0-auc:0.86310
# [18]	validation_0-auc:0.86303
# [19]	validation_0-auc:0.86350
# [20]	validation_0-auc:0.86338
# [21]	validation_0-auc:0.86332
# [22]	validation_0-auc:0.86334
# [23]	validation_0-auc:0.86360
# [24]	validation_0-auc:0.86353
# [25]	validation_0-auc:0.86350
# [26]	validation_0-auc:0.86347
# [27]	validation_0-auc:0.86339
# [28]	validation_0-auc:0.86379
# [29]	validation_0-auc:0.86375
# [30]	validation_0-auc:0.86407
# [31]	validation_0-auc:0.86404
# [32]	validation_0-auc:0.86406
# [33]	validation_0-auc:0.86404
# [34]	validation_0-auc:0.86405
# [35]	validation_0-auc:0.86401
# [36]	validation_0-auc:0.86399
# [37]	validation_0-auc:0.86398
# [38]	validation_0-auc:0.86396
# [39]	validation_0-auc:0.86393
# [40]	validation_0-auc:0.86390
# [41]	validation_0-auc:0.86394
# [42]	validation_0-auc:0.86389
# [43]	validation_0-auc:0.86386
# [44]	validation_0-auc:0.86396
# [45]	validation_0-auc:0.86398
# [46]	validation_0-auc:0.86395
# [47]	validation_0-auc:0.86391
# [48]	validation_0-auc:0.86391
# [49]	validation_0-auc:0.86389
# [50]	validation_0-auc:0.86413
# [51]	validation_0-auc:0.86431
# [52]	validation_0-auc:0.86429
# [53]	validation_0-auc:0.86458
# [54]	validation_0-auc:0.86455
# [55]	validation_0-auc:0.86451
# [56]	validation_0-auc:0.86450
# [57]	validation_0-auc:0.86449
# [58]	validation_0-auc:0.86446
# [59]	validation_0-auc:0.86443
# [60]	validation_0-auc:0.86442
# [61]	validation_0-auc:0.86441
# [62]	validation_0-auc:0.86437
# [63]	validation_0-auc:0.86435
# [64]	validation_0-auc:0.86432
# [65]	validation_0-auc:0.86437
# [66]	validation_0-auc:0.86434
# [67]	validation_0-auc:0.86432
# [68]	validation_0-auc:0.86431
# [69]	validation_0-auc:0.86430
# [70]	validation_0-auc:0.86430
# [71]	validation_0-auc:0.86434
# [72]	validation_0-auc:0.86431
# [73]	validation_0-auc:0.86439
# [0]	validation_0-auc:0.83612
# [1]	validation_0-auc:0.85912
# [2]	validation_0-auc:0.86016
# [3]	validation_0-auc:0.86075
# [4]	validation_0-auc:0.86124
# [5]	validation_0-auc:0.86118
# [6]	validation_0-auc:0.86146
# [7]	validation_0-auc:0.86190
# [8]	validation_0-auc:0.86198
# [9]	validation_0-auc:0.86230
# [10]	validation_0-auc:0.86226
# [11]	validation_0-auc:0.86216
# [12]	validation_0-auc:0.86269
# [13]	validation_0-auc:0.86265
# [14]	validation_0-auc:0.86310
# [15]	validation_0-auc:0.86312
# [16]	validation_0-auc:0.86318
# [17]	validation_0-auc:0.86315
# [18]	validation_0-auc:0.86309
# [19]	validation_0-auc:0.86334
# [20]	validation_0-auc:0.86323
# [21]	validation_0-auc:0.86318
# [22]	validation_0-auc:0.86326
# [23]	validation_0-auc:0.86377
# [24]	validation_0-auc:0.86369
# [25]	validation_0-auc:0.86366
# [26]	validation_0-auc:0.86361
# [27]	validation_0-auc:0.86353
# [28]	validation_0-auc:0.86383
# [29]	validation_0-auc:0.86383
# [30]	validation_0-auc:0.86417
# [31]	validation_0-auc:0.86420
# [32]	validation_0-auc:0.86423
# [33]	validation_0-auc:0.86420
# [34]	validation_0-auc:0.86420
# [35]	validation_0-auc:0.86415
# [36]	validation_0-auc:0.86413
# [37]	validation_0-auc:0.86411
# [38]	validation_0-auc:0.86410
# [39]	validation_0-auc:0.86408
# [40]	validation_0-auc:0.86405
# [41]	validation_0-auc:0.86411
# [42]	validation_0-auc:0.86408
# [43]	validation_0-auc:0.86405
# [44]	validation_0-auc:0.86413
# [45]	validation_0-auc:0.86416
# [46]	validation_0-auc:0.86414
# [47]	validation_0-auc:0.86411
# [48]	validation_0-auc:0.86411
# [49]	validation_0-auc:0.86409
# [50]	validation_0-auc:0.86432
# [51]	validation_0-auc:0.86451
# [52]	validation_0-auc:0.86447
# [53]	validation_0-auc:0.86461
# [54]	validation_0-auc:0.86459
# [55]	validation_0-auc:0.86456
# [56]	validation_0-auc:0.86455
# [57]	validation_0-auc:0.86454
# [58]	validation_0-auc:0.86450
# [59]	validation_0-auc:0.86447
# [60]	validation_0-auc:0.86446
# [61]	validation_0-auc:0.86446
# [62]	validation_0-auc:0.86442
# [63]	validation_0-auc:0.86443
# [64]	validation_0-auc:0.86440
# [65]	validation_0-auc:0.86439
# [66]	validation_0-auc:0.86436
# [67]	validation_0-auc:0.86432
# [68]	validation_0-auc:0.86432
# [69]	validation_0-auc:0.86431
# [70]	validation_0-auc:0.86428
# [71]	validation_0-auc:0.86437
# [72]	validation_0-auc:0.86436
# [73]	validation_0-auc:0.86444
# [0]	validation_0-auc:0.83452
# [1]	validation_0-auc:0.85883
# [2]	validation_0-auc:0.86041
# [3]	validation_0-auc:0.86083
# [4]	validation_0-auc:0.86120
# [5]	validation_0-auc:0.86125
# [6]	validation_0-auc:0.86150
# [7]	validation_0-auc:0.86189
# [8]	validation_0-auc:0.86194
# [9]	validation_0-auc:0.86300
# [10]	validation_0-auc:0.86290
# [11]	validation_0-auc:0.86282
# [12]	validation_0-auc:0.86373
# [13]	validation_0-auc:0.86357
# [14]	validation_0-auc:0.86403
# [15]	validation_0-auc:0.86414
# [16]	validation_0-auc:0.86409
# [17]	validation_0-auc:0.86401
# [18]	validation_0-auc:0.86390
# [19]	validation_0-auc:0.86414
# [20]	validation_0-auc:0.86404
# [21]	validation_0-auc:0.86401
# [22]	validation_0-auc:0.86399
# [23]	validation_0-auc:0.86445
# [24]	validation_0-auc:0.86436
# [25]	validation_0-auc:0.86431
# [26]	validation_0-auc:0.86423
# [27]	validation_0-auc:0.86416
# [28]	validation_0-auc:0.86451
# [29]	validation_0-auc:0.86445
# [30]	validation_0-auc:0.86476
# [31]	validation_0-auc:0.86470
# [32]	validation_0-auc:0.86471
# [33]	validation_0-auc:0.86467
# [34]	validation_0-auc:0.86469
# [35]	validation_0-auc:0.86465
# [36]	validation_0-auc:0.86460
# [37]	validation_0-auc:0.86459
# [38]	validation_0-auc:0.86456
# [39]	validation_0-auc:0.86449
# [40]	validation_0-auc:0.86445
# [41]	validation_0-auc:0.86448
# [42]	validation_0-auc:0.86446
# [43]	validation_0-auc:0.86444
# [44]	validation_0-auc:0.86455
# [45]	validation_0-auc:0.86454
# [46]	validation_0-auc:0.86452
# [47]	validation_0-auc:0.86449
# [48]	validation_0-auc:0.86448
# [49]	validation_0-auc:0.86447
# [50]	validation_0-auc:0.86472
#   4%|█▊                                           | 1/25 [13:46<5:30:38, 826.62s/trial, best loss: -0.8646522719393364]
# C:\Users\OSY\anaconda3\envs\osy\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [0]	validation_0-auc:0.83978
# [1]	validation_0-auc:0.85783
# [2]	validation_0-auc:0.85897
# [3]	validation_0-auc:0.85911
# [4]	validation_0-auc:0.85880
# [5]	validation_0-auc:0.85852
# [6]	validation_0-auc:0.85870
# [7]	validation_0-auc:0.85873
# [8]	validation_0-auc:0.85942
# [9]	validation_0-auc:0.86040
# [10]	validation_0-auc:0.86031
# [11]	validation_0-auc:0.86045
# [12]	validation_0-auc:0.86053
# [13]	validation_0-auc:0.86042
# [14]	validation_0-auc:0.86036
# [15]	validation_0-auc:0.86086
# [16]	validation_0-auc:0.86079
# [17]	validation_0-auc:0.86066
# [18]	validation_0-auc:0.86075
# [19]	validation_0-auc:0.86066
# [20]	validation_0-auc:0.86057
# [21]	validation_0-auc:0.86058
# [22]	validation_0-auc:0.86059
# [23]	validation_0-auc:0.86095
# [24]	validation_0-auc:0.86101
# [25]	validation_0-auc:0.86099
# [26]	validation_0-auc:0.86089
# [27]	validation_0-auc:0.86091
# [28]	validation_0-auc:0.86084
# [29]	validation_0-auc:0.86085
# [30]	validation_0-auc:0.86084
# [31]	validation_0-auc:0.86086
# [32]	validation_0-auc:0.86089
# [33]	validation_0-auc:0.86089
# [34]	validation_0-auc:0.86088
# [35]	validation_0-auc:0.86089
# [36]	validation_0-auc:0.86090
# [37]	validation_0-auc:0.86129
# [38]	validation_0-auc:0.86126
# [39]	validation_0-auc:0.86123
# [40]	validation_0-auc:0.86120
# [41]	validation_0-auc:0.86119
# [42]	validation_0-auc:0.86113
# [43]	validation_0-auc:0.86116
# [44]	validation_0-auc:0.86117
# [45]	validation_0-auc:0.86114
# [46]	validation_0-auc:0.86109
# [47]	validation_0-auc:0.86107
# [48]	validation_0-auc:0.86103
# [49]	validation_0-auc:0.86103
# [50]	validation_0-auc:0.86105
# [51]	validation_0-auc:0.86107
# [52]	validation_0-auc:0.86103
# [53]	validation_0-auc:0.86103
# [54]	validation_0-auc:0.86100
# [55]	validation_0-auc:0.86104
# [56]	validation_0-auc:0.86105
# [57]	validation_0-auc:0.86111
# [0]	validation_0-auc:0.84000
# [1]	validation_0-auc:0.85798
# [2]	validation_0-auc:0.85843
# [3]	validation_0-auc:0.85870
# [4]	validation_0-auc:0.85858
# [5]	validation_0-auc:0.85843
# [6]	validation_0-auc:0.85885
# [7]	validation_0-auc:0.85866
# [8]	validation_0-auc:0.85968
# [9]	validation_0-auc:0.85994
# [10]	validation_0-auc:0.85983
# [11]	validation_0-auc:0.86000
# [12]	validation_0-auc:0.86002
# [13]	validation_0-auc:0.86001
# [14]	validation_0-auc:0.85996
# [15]	validation_0-auc:0.86043
# [16]	validation_0-auc:0.86062
# [17]	validation_0-auc:0.86052
# [18]	validation_0-auc:0.86049
# [19]	validation_0-auc:0.86037
# [20]	validation_0-auc:0.86046
# [21]	validation_0-auc:0.86052
# [22]	validation_0-auc:0.86061
# [23]	validation_0-auc:0.86096
# [24]	validation_0-auc:0.86101
# [25]	validation_0-auc:0.86101
# [26]	validation_0-auc:0.86091
# [27]	validation_0-auc:0.86099
# [28]	validation_0-auc:0.86098
# [29]	validation_0-auc:0.86095
# [30]	validation_0-auc:0.86091
# [31]	validation_0-auc:0.86094
# [32]	validation_0-auc:0.86091
# [33]	validation_0-auc:0.86089
# [34]	validation_0-auc:0.86087
# [35]	validation_0-auc:0.86086
# [36]	validation_0-auc:0.86086
# [37]	validation_0-auc:0.86125
# [38]	validation_0-auc:0.86122
# [39]	validation_0-auc:0.86119
# [40]	validation_0-auc:0.86112
# [41]	validation_0-auc:0.86107
# [42]	validation_0-auc:0.86106
# [43]	validation_0-auc:0.86104
# [44]	validation_0-auc:0.86103
# [45]	validation_0-auc:0.86104
# [46]	validation_0-auc:0.86104
# [47]	validation_0-auc:0.86109
# [48]	validation_0-auc:0.86107
# [49]	validation_0-auc:0.86109
# [50]	validation_0-auc:0.86108
# [51]	validation_0-auc:0.86109
# [52]	validation_0-auc:0.86106
# [53]	validation_0-auc:0.86104
# [54]	validation_0-auc:0.86115
# [55]	validation_0-auc:0.86117
# [56]	validation_0-auc:0.86117
# [57]	validation_0-auc:0.86122
# [0]	validation_0-auc:0.83863
# [1]	validation_0-auc:0.85859
# [2]	validation_0-auc:0.85904
# [3]	validation_0-auc:0.85913
# [4]	validation_0-auc:0.85895
# [5]	validation_0-auc:0.85870
# [6]	validation_0-auc:0.85881
# [7]	validation_0-auc:0.85860
# [8]	validation_0-auc:0.85983
# [9]	validation_0-auc:0.86053
# [10]	validation_0-auc:0.86045
# [11]	validation_0-auc:0.86103
# [12]	validation_0-auc:0.86138
# [13]	validation_0-auc:0.86122
# [14]	validation_0-auc:0.86114
# [15]	validation_0-auc:0.86127
# [16]	validation_0-auc:0.86116
# [17]	validation_0-auc:0.86098
# [18]	validation_0-auc:0.86084
# [19]	validation_0-auc:0.86082
# [20]	validation_0-auc:0.86073
# [21]	validation_0-auc:0.86065
# [22]	validation_0-auc:0.86079
# [23]	validation_0-auc:0.86089
# [24]	validation_0-auc:0.86090
# [25]	validation_0-auc:0.86090
# [26]	validation_0-auc:0.86095
# [27]	validation_0-auc:0.86097
# [28]	validation_0-auc:0.86101
# [29]	validation_0-auc:0.86102
# [30]	validation_0-auc:0.86096
# [31]	validation_0-auc:0.86099
# [32]	validation_0-auc:0.86105
#   8%|███▌                                         | 2/25 [19:03<3:21:54, 526.72s/trial, best loss: -0.8646522719393364]
# C:\Users\OSY\anaconda3\envs\osy\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [0]	validation_0-auc:0.84087
# [1]	validation_0-auc:0.85878
# [2]	validation_0-auc:0.86019
# [3]	validation_0-auc:0.86055
# [4]	validation_0-auc:0.86067
# [5]	validation_0-auc:0.86075
# [6]	validation_0-auc:0.86243
# [7]	validation_0-auc:0.86241
# [8]	validation_0-auc:0.86324
# [9]	validation_0-auc:0.86461
# [10]	validation_0-auc:0.86466
# [11]	validation_0-auc:0.86495
# [12]	validation_0-auc:0.86520
# [13]	validation_0-auc:0.86534
# [14]	validation_0-auc:0.86536
# [15]	validation_0-auc:0.86696
# [16]	validation_0-auc:0.86694
# [17]	validation_0-auc:0.86698
# [18]	validation_0-auc:0.86706
# [19]	validation_0-auc:0.86721
# [20]	validation_0-auc:0.86725
# [21]	validation_0-auc:0.86743
# [22]	validation_0-auc:0.86903
# [23]	validation_0-auc:0.87016
# [24]	validation_0-auc:0.87101
# [25]	validation_0-auc:0.87140
# [26]	validation_0-auc:0.87145
# [27]	validation_0-auc:0.87160
# [28]	validation_0-auc:0.87177
# [29]	validation_0-auc:0.87254
# [30]	validation_0-auc:0.87271
# [31]	validation_0-auc:0.87310
# [32]	validation_0-auc:0.87326
# [33]	validation_0-auc:0.87330
# [34]	validation_0-auc:0.87339
# [35]	validation_0-auc:0.87345
# [36]	validation_0-auc:0.87384
# [37]	validation_0-auc:0.87395
# [38]	validation_0-auc:0.87402
# [39]	validation_0-auc:0.87404
# [40]	validation_0-auc:0.87412
# [41]	validation_0-auc:0.87432
# [42]	validation_0-auc:0.87436
# [43]	validation_0-auc:0.87465
# [44]	validation_0-auc:0.87471
# [45]	validation_0-auc:0.87476
# [46]	validation_0-auc:0.87485
# ...
# [387]	validation_0-auc:0.88152
# [388]	validation_0-auc:0.88152
# [389]	validation_0-auc:0.88152
# [390]	validation_0-auc:0.88152
# [391]	validation_0-auc:0.88152
# [392]	validation_0-auc:0.88152
# [393]	validation_0-auc:0.88152
# [394]	validation_0-auc:0.88152
# [395]	validation_0-auc:0.88152
# [396]	validation_0-auc:0.88152
# [397]	validation_0-auc:0.88152
# [398]	validation_0-auc:0.88152
# [399]	validation_0-auc:0.88153
# [400]	validation_0-auc:0.88153
# [401]	validation_0-auc:0.88153
# [402]	validation_0-auc:0.88153
# [403]	validation_0-auc:0.88153
# [404]	validation_0-auc:0.88153
# [405]	validation_0-auc:0.88153
# [406]	validation_0-auc:0.88153
# [407]	validation_0-auc:0.88153
# [408]	validation_0-auc:0.88153
# [409]	validation_0-auc:0.88153
# [410]	validation_0-auc:0.88153
# [411]	validation_0-auc:0.88153
# [412]	validation_0-auc:0.88154
# [413]	validation_0-auc:0.88154
# [414]	validation_0-auc:0.88155
# [415]	validation_0-auc:0.88155
# [416]	validation_0-auc:0.88155
# [417]	validation_0-auc:0.88156
# [418]	validation_0-auc:0.88156
# [419]	validation_0-auc:0.88156
# [420]	validation_0-auc:0.88157
# [421]	validation_0-auc:0.88157
# [422]	validation_0-auc:0.88157
# [423]	validation_0-auc:0.88157
# [424]	validation_0-auc:0.88157
# [425]	validation_0-auc:0.88158
# [426]	validation_0-auc:0.88158
# [427]	validation_0-auc:0.88157
# [428]	validation_0-auc:0.88158
# [429]	validation_0-auc:0.88158
# [430]	validation_0-auc:0.88157
# [431]	validation_0-auc:0.88158
# [432]	validation_0-auc:0.88158
# [433]	validation_0-auc:0.88158
# [434]	validation_0-auc:0.88158
# [435]	validation_0-auc:0.88158
# [436]	validation_0-auc:0.88158
# [437]	validation_0-auc:0.88159
# [438]	validation_0-auc:0.88159
# [439]	validation_0-auc:0.88159
# [440]	validation_0-auc:0.88159
# [441]	validation_0-auc:0.88159
# [442]	validation_0-auc:0.88159
# [443]	validation_0-auc:0.88160
# [444]	validation_0-auc:0.88160
# [445]	validation_0-auc:0.88160
# [446]	validation_0-auc:0.88160
# [447]	validation_0-auc:0.88160
# [448]	validation_0-auc:0.88160
# [449]	validation_0-auc:0.88161
# [450]	validation_0-auc:0.88161
# [451]	validation_0-auc:0.88161
# [452]	validation_0-auc:0.88161
# [453]	validation_0-auc:0.88161
# [454]	validation_0-auc:0.88161
# [455]	validation_0-auc:0.88161
# [456]	validation_0-auc:0.88161
# [457]	validation_0-auc:0.88162
# [458]	validation_0-auc:0.88162
# [459]	validation_0-auc:0.88162
# [460]	validation_0-auc:0.88162
# [461]	validation_0-auc:0.88162
# [462]	validation_0-auc:0.88162
# [463]	validation_0-auc:0.88162
# [464]	validation_0-auc:0.88162
# [465]	validation_0-auc:0.88162
# [466]	validation_0-auc:0.88163
# [467]	validation_0-auc:0.88162
# [468]	validation_0-auc:0.88162
# [469]	validation_0-auc:0.88163
# [470]	validation_0-auc:0.88163
# [471]	validation_0-auc:0.88162
# [472]	validation_0-auc:0.88162
# [473]	validation_0-auc:0.88162
# [474]	validation_0-auc:0.88163
# [475]	validation_0-auc:0.88163
# [476]	validation_0-auc:0.88163
# [477]	validation_0-auc:0.88163
# [478]	validation_0-auc:0.88163
# [479]	validation_0-auc:0.88164
# [480]	validation_0-auc:0.88164
# [481]	validation_0-auc:0.88164
# [482]	validation_0-auc:0.88164
# [483]	validation_0-auc:0.88164
# [484]	validation_0-auc:0.88164
# [485]	validation_0-auc:0.88164
# [486]	validation_0-auc:0.88164
# [487]	validation_0-auc:0.88164
# [488]	validation_0-auc:0.88164
# [489]	validation_0-auc:0.88164
# [490]	validation_0-auc:0.88164
# [491]	validation_0-auc:0.88164
# [492]	validation_0-auc:0.88164
# [493]	validation_0-auc:0.88165
# [494]	validation_0-auc:0.88165
# [495]	validation_0-auc:0.88165
# [496]	validation_0-auc:0.88165
# [497]	validation_0-auc:0.88166
# [498]	validation_0-auc:0.88166
# [499]	validation_0-auc:0.88166
# [500]	validation_0-auc:0.88166
# [501]	validation_0-auc:0.88166
# [502]	validation_0-auc:0.88166
# [503]	validation_0-auc:0.88166
# [504]	validation_0-auc:0.88166
# [505]	validation_0-auc:0.88166
# [506]	validation_0-auc:0.88166
# [507]	validation_0-auc:0.88166
# [508]	validation_0-auc:0.88165
# [509]	validation_0-auc:0.88166
# [510]	validation_0-auc:0.88166
# [511]	validation_0-auc:0.88166
# [512]	validation_0-auc:0.88166
# [513]	validation_0-auc:0.88166
# [514]	validation_0-auc:0.88166
# [515]	validation_0-auc:0.88166
# [516]	validation_0-auc:0.88166
# [517]	validation_0-auc:0.88166
# [518]	validation_0-auc:0.88166
# [519]	validation_0-auc:0.88165
# 100%|██████████████████████████████████████████| 25/25 [16:49:46<00:00, 2423.46s/trial, best loss: -0.8814746853291714]

# %%
print("Best parameters found: ", best)
# Out:
# Best parameters found:  {'colsample_bytree': 0.527109065831463, 'learning_rate': 0.11264881448753765, 'max_depth': 10.0, 'min_child_weight': 7.0, 'n_estimators': 503.0, 'scale_pos_weight': 8.418579225674955, 'subsample': 0.815258700719608}

# %%
best_params = {
    'n_estimators': int(best['n_estimators']),
    'learning_rate': best['learning_rate'],
    'min_child_weight': int(best['min_child_weight']),  
    'max_depth': int(best['max_depth']),
    'subsample': best['subsample'],
    'colsample_bytree': best['colsample_bytree'],
    'scale_pos_weight': best['scale_pos_weight'],
    'n_jobs': -1
}

# %%
best_Xgb = XGBClassifier(**best_params,early_stopping_rounds=20,eval_metric='auc')
best_Xgb.fit(x_train, y_train,eval_set=[(x_val, y_val)],verbose=True)
# Out:
# [0]	validation_0-auc:0.83243
# [1]	validation_0-auc:0.85717
# [2]	validation_0-auc:0.85708
# [3]	validation_0-auc:0.86159
# [4]	validation_0-auc:0.86107
# [5]	validation_0-auc:0.86217
# [6]	validation_0-auc:0.86188
# [7]	validation_0-auc:0.86139
# [8]	validation_0-auc:0.86223
# [9]	validation_0-auc:0.86547
# [10]	validation_0-auc:0.86530
# [11]	validation_0-auc:0.86591
# [12]	validation_0-auc:0.86623
# [13]	validation_0-auc:0.86597
# [14]	validation_0-auc:0.86889
# [15]	validation_0-auc:0.86962
# [16]	validation_0-auc:0.87047
# [17]	validation_0-auc:0.87067
# [18]	validation_0-auc:0.87063
# [19]	validation_0-auc:0.87192
# [20]	validation_0-auc:0.87225
# [21]	validation_0-auc:0.87233
# [22]	validation_0-auc:0.87267
# [23]	validation_0-auc:0.87314
# [24]	validation_0-auc:0.87327
# [25]	validation_0-auc:0.87329
# [26]	validation_0-auc:0.87344
# [27]	validation_0-auc:0.87356
# [28]	validation_0-auc:0.87386
# [29]	validation_0-auc:0.87410
# [30]	validation_0-auc:0.87419
# [31]	validation_0-auc:0.87424
# [32]	validation_0-auc:0.87422
# [33]	validation_0-auc:0.87419
# [34]	validation_0-auc:0.87432
# [35]	validation_0-auc:0.87438
# [36]	validation_0-auc:0.87471
# [37]	validation_0-auc:0.87477
# [38]	validation_0-auc:0.87483
# [39]	validation_0-auc:0.87493
# [40]	validation_0-auc:0.87495
# [41]	validation_0-auc:0.87499
# [42]	validation_0-auc:0.87504
# [43]	validation_0-auc:0.87505
# [44]	validation_0-auc:0.87510
# [45]	validation_0-auc:0.87538
# [46]	validation_0-auc:0.87538
# [47]	validation_0-auc:0.87539
# [48]	validation_0-auc:0.87538
# [49]	validation_0-auc:0.87573
# [50]	validation_0-auc:0.87596
# [51]	validation_0-auc:0.87609
# [52]	validation_0-auc:0.87627
# [53]	validation_0-auc:0.87665
# [54]	validation_0-auc:0.87668
# [55]	validation_0-auc:0.87677
# [56]	validation_0-auc:0.87686
# [57]	validation_0-auc:0.87693
# [58]	validation_0-auc:0.87693
# [59]	validation_0-auc:0.87698
# [60]	validation_0-auc:0.87703
# [61]	validation_0-auc:0.87704
# [62]	validation_0-auc:0.87708
# [63]	validation_0-auc:0.87724
# [64]	validation_0-auc:0.87737
# [65]	validation_0-auc:0.87755
# [66]	validation_0-auc:0.87757
# [67]	validation_0-auc:0.87764
# [68]	validation_0-auc:0.87773
# [69]	validation_0-auc:0.87780
# [70]	validation_0-auc:0.87781
# [71]	validation_0-auc:0.87790
# [72]	validation_0-auc:0.87795
# [73]	validation_0-auc:0.87796
# [74]	validation_0-auc:0.87798
# [75]	validation_0-auc:0.87817
# [76]	validation_0-auc:0.87827
# [77]	validation_0-auc:0.87828
# [78]	validation_0-auc:0.87835
# [79]	validation_0-auc:0.87844
# [80]	validation_0-auc:0.87846
# [81]	validation_0-auc:0.87856
# [82]	validation_0-auc:0.87862
# [83]	validation_0-auc:0.87869
# [84]	validation_0-auc:0.87870
# [85]	validation_0-auc:0.87876
# [86]	validation_0-auc:0.87879
# [87]	validation_0-auc:0.87882
# [88]	validation_0-auc:0.87887
# [89]	validation_0-auc:0.87892
# [90]	validation_0-auc:0.87895
# [91]	validation_0-auc:0.87896
# [92]	validation_0-auc:0.87899
# [93]	validation_0-auc:0.87901
# [94]	validation_0-auc:0.87902
# [95]	validation_0-auc:0.87904
# [96]	validation_0-auc:0.87910
# [97]	validation_0-auc:0.87918
# [98]	validation_0-auc:0.87922
# [99]	validation_0-auc:0.87927
# [100]	validation_0-auc:0.87929
# [101]	validation_0-auc:0.87929
# [102]	validation_0-auc:0.87932
# [103]	validation_0-auc:0.87932
# [104]	validation_0-auc:0.87935
# [105]	validation_0-auc:0.87938
# [106]	validation_0-auc:0.87945
# [107]	validation_0-auc:0.87946
# [108]	validation_0-auc:0.87948
# [109]	validation_0-auc:0.87951
# [110]	validation_0-auc:0.87953
# [111]	validation_0-auc:0.87953
# [112]	validation_0-auc:0.87953
# [113]	validation_0-auc:0.87957
# [114]	validation_0-auc:0.87961
# [115]	validation_0-auc:0.87962
# [116]	validation_0-auc:0.87963
# [117]	validation_0-auc:0.87964
# [118]	validation_0-auc:0.87965
# [119]	validation_0-auc:0.87969
# [120]	validation_0-auc:0.87970
# [121]	validation_0-auc:0.87971
# [122]	validation_0-auc:0.87973
# [123]	validation_0-auc:0.87974
# [124]	validation_0-auc:0.87976
# [125]	validation_0-auc:0.87977
# [126]	validation_0-auc:0.87977
# [127]	validation_0-auc:0.87979
# [128]	validation_0-auc:0.87985
# [129]	validation_0-auc:0.87987
# [130]	validation_0-auc:0.87994
# [131]	validation_0-auc:0.87997
# [132]	validation_0-auc:0.88001
# [133]	validation_0-auc:0.88002
# [134]	validation_0-auc:0.88003
# [135]	validation_0-auc:0.88008
# [136]	validation_0-auc:0.88009
# [137]	validation_0-auc:0.88011
# [138]	validation_0-auc:0.88013
# [139]	validation_0-auc:0.88013
# [140]	validation_0-auc:0.88014
# [141]	validation_0-auc:0.88014
# [142]	validation_0-auc:0.88016
# [143]	validation_0-auc:0.88019
# [144]	validation_0-auc:0.88021
# [145]	validation_0-auc:0.88025
# [146]	validation_0-auc:0.88026
# [147]	validation_0-auc:0.88028
# [148]	validation_0-auc:0.88030
# [149]	validation_0-auc:0.88032
# [150]	validation_0-auc:0.88032
# [151]	validation_0-auc:0.88034
# [152]	validation_0-auc:0.88034
# [153]	validation_0-auc:0.88034
# [154]	validation_0-auc:0.88035
# [155]	validation_0-auc:0.88037
# [156]	validation_0-auc:0.88037
# [157]	validation_0-auc:0.88037
# [158]	validation_0-auc:0.88039
# [159]	validation_0-auc:0.88040
# [160]	validation_0-auc:0.88040
# [161]	validation_0-auc:0.88040
# [162]	validation_0-auc:0.88041
# [163]	validation_0-auc:0.88042
# [164]	validation_0-auc:0.88043
# [165]	validation_0-auc:0.88044
# [166]	validation_0-auc:0.88044
# [167]	validation_0-auc:0.88044
# [168]	validation_0-auc:0.88045
# [169]	validation_0-auc:0.88045
# [170]	validation_0-auc:0.88048
# [171]	validation_0-auc:0.88048
# [172]	validation_0-auc:0.88051
# [173]	validation_0-auc:0.88054
# [174]	validation_0-auc:0.88054
# [175]	validation_0-auc:0.88055
# [176]	validation_0-auc:0.88057
# [177]	validation_0-auc:0.88058
# [178]	validation_0-auc:0.88058
# [179]	validation_0-auc:0.88059
# [180]	validation_0-auc:0.88060
# [181]	validation_0-auc:0.88060
# [182]	validation_0-auc:0.88060
# [183]	validation_0-auc:0.88061
# [184]	validation_0-auc:0.88063
# [185]	validation_0-auc:0.88063
# [186]	validation_0-auc:0.88065
# [187]	validation_0-auc:0.88066
# [188]	validation_0-auc:0.88067
# [189]	validation_0-auc:0.88068
# [190]	validation_0-auc:0.88069
# [191]	validation_0-auc:0.88069
# [192]	validation_0-auc:0.88070
# [193]	validation_0-auc:0.88070
# [194]	validation_0-auc:0.88071
# [195]	validation_0-auc:0.88072
# [196]	validation_0-auc:0.88073
# [197]	validation_0-auc:0.88075
# [198]	validation_0-auc:0.88076
# [199]	validation_0-auc:0.88076
# [200]	validation_0-auc:0.88077
# [201]	validation_0-auc:0.88078
# [202]	validation_0-auc:0.88079
# [203]	validation_0-auc:0.88079
# [204]	validation_0-auc:0.88081
# [205]	validation_0-auc:0.88082
# [206]	validation_0-auc:0.88083
# [207]	validation_0-auc:0.88085
# [208]	validation_0-auc:0.88085
# [209]	validation_0-auc:0.88085
# [210]	validation_0-auc:0.88086
# [211]	validation_0-auc:0.88087
# [212]	validation_0-auc:0.88089
# [213]	validation_0-auc:0.88089
# [214]	validation_0-auc:0.88090
# [215]	validation_0-auc:0.88091
# [216]	validation_0-auc:0.88091
# [217]	validation_0-auc:0.88093
# [218]	validation_0-auc:0.88094
# [219]	validation_0-auc:0.88095
# [220]	validation_0-auc:0.88096
# [221]	validation_0-auc:0.88096
# [222]	validation_0-auc:0.88096
# [223]	validation_0-auc:0.88097
# [224]	validation_0-auc:0.88097
# [225]	validation_0-auc:0.88099
# [226]	validation_0-auc:0.88100
# [227]	validation_0-auc:0.88100
# [228]	validation_0-auc:0.88100
# [229]	validation_0-auc:0.88101
# [230]	validation_0-auc:0.88101
# [231]	validation_0-auc:0.88102
# [232]	validation_0-auc:0.88103
# [233]	validation_0-auc:0.88103
# [234]	validation_0-auc:0.88103
# [235]	validation_0-auc:0.88104
# [236]	validation_0-auc:0.88105
# [237]	validation_0-auc:0.88105
# [238]	validation_0-auc:0.88106
# [239]	validation_0-auc:0.88106
# [240]	validation_0-auc:0.88106
# [241]	validation_0-auc:0.88106
# [242]	validation_0-auc:0.88107
# [243]	validation_0-auc:0.88107
# [244]	validation_0-auc:0.88107
# [245]	validation_0-auc:0.88108
# [246]	validation_0-auc:0.88109
# [247]	validation_0-auc:0.88109
# [248]	validation_0-auc:0.88110
# [249]	validation_0-auc:0.88110
# [250]	validation_0-auc:0.88111
# [251]	validation_0-auc:0.88112
# [252]	validation_0-auc:0.88112
# [253]	validation_0-auc:0.88113
# [254]	validation_0-auc:0.88113
# [255]	validation_0-auc:0.88114
# [256]	validation_0-auc:0.88115
# [257]	validation_0-auc:0.88115
# [258]	validation_0-auc:0.88116
# [259]	validation_0-auc:0.88116
# [260]	validation_0-auc:0.88116
# [261]	validation_0-auc:0.88117
# [262]	validation_0-auc:0.88117
# [263]	validation_0-auc:0.88117
# [264]	validation_0-auc:0.88118
# [265]	validation_0-auc:0.88119
# [266]	validation_0-auc:0.88119
# [267]	validation_0-auc:0.88120
# [268]	validation_0-auc:0.88120
# [269]	validation_0-auc:0.88120
# [270]	validation_0-auc:0.88121
# [271]	validation_0-auc:0.88121
# [272]	validation_0-auc:0.88122
# [273]	validation_0-auc:0.88122
# [274]	validation_0-auc:0.88123
# [275]	validation_0-auc:0.88123
# [276]	validation_0-auc:0.88123
# [277]	validation_0-auc:0.88124
# [278]	validation_0-auc:0.88124
# [279]	validation_0-auc:0.88124
# [280]	validation_0-auc:0.88124
# [281]	validation_0-auc:0.88124
# [282]	validation_0-auc:0.88126
# [283]	validation_0-auc:0.88126
# [284]	validation_0-auc:0.88127
# [285]	validation_0-auc:0.88127
# [286]	validation_0-auc:0.88127
# [287]	validation_0-auc:0.88127
# [288]	validation_0-auc:0.88128
# [289]	validation_0-auc:0.88128
# [290]	validation_0-auc:0.88129
# [291]	validation_0-auc:0.88129
# [292]	validation_0-auc:0.88129
# [293]	validation_0-auc:0.88130
# [294]	validation_0-auc:0.88130
# [295]	validation_0-auc:0.88130
# [296]	validation_0-auc:0.88131
# [297]	validation_0-auc:0.88132
# [298]	validation_0-auc:0.88133
# [299]	validation_0-auc:0.88133
# [300]	validation_0-auc:0.88133
# [301]	validation_0-auc:0.88133
# [302]	validation_0-auc:0.88133
# [303]	validation_0-auc:0.88134
# [304]	validation_0-auc:0.88133
# [305]	validation_0-auc:0.88134
# [306]	validation_0-auc:0.88134
# [307]	validation_0-auc:0.88135
# [308]	validation_0-auc:0.88135
# [309]	validation_0-auc:0.88135
# [310]	validation_0-auc:0.88135
# [311]	validation_0-auc:0.88135
# [312]	validation_0-auc:0.88135
# [313]	validation_0-auc:0.88137
# [314]	validation_0-auc:0.88136
# [315]	validation_0-auc:0.88137
# [316]	validation_0-auc:0.88137
# [317]	validation_0-auc:0.88137
# [318]	validation_0-auc:0.88139
# [319]	validation_0-auc:0.88139
# [320]	validation_0-auc:0.88139
# [321]	validation_0-auc:0.88139
# [322]	validation_0-auc:0.88139
# [323]	validation_0-auc:0.88139
# [324]	validation_0-auc:0.88140
# [325]	validation_0-auc:0.88140
# [326]	validation_0-auc:0.88140
# [327]	validation_0-auc:0.88140
# [328]	validation_0-auc:0.88140
# [329]	validation_0-auc:0.88141
# [330]	validation_0-auc:0.88141
# [331]	validation_0-auc:0.88141
# [332]	validation_0-auc:0.88142
# [333]	validation_0-auc:0.88143
# [334]	validation_0-auc:0.88143
# [335]	validation_0-auc:0.88144
# [336]	validation_0-auc:0.88144
# [337]	validation_0-auc:0.88145
# [338]	validation_0-auc:0.88146
# [339]	validation_0-auc:0.88146
# [340]	validation_0-auc:0.88146
# [341]	validation_0-auc:0.88147
# [342]	validation_0-auc:0.88147
# [343]	validation_0-auc:0.88147
# [344]	validation_0-auc:0.88148
# [345]	validation_0-auc:0.88148
# [346]	validation_0-auc:0.88149
# [347]	validation_0-auc:0.88149
# [348]	validation_0-auc:0.88149
# [349]	validation_0-auc:0.88149
# [350]	validation_0-auc:0.88150
# [351]	validation_0-auc:0.88150
# [352]	validation_0-auc:0.88150
# [353]	validation_0-auc:0.88150
# [354]	validation_0-auc:0.88151
# [355]	validation_0-auc:0.88150
# [356]	validation_0-auc:0.88151
# [357]	validation_0-auc:0.88151
# [358]	validation_0-auc:0.88152
# [359]	validation_0-auc:0.88152
# [360]	validation_0-auc:0.88152
# [361]	validation_0-auc:0.88153
# [362]	validation_0-auc:0.88153
# [363]	validation_0-auc:0.88153
# [364]	validation_0-auc:0.88153
# [365]	validation_0-auc:0.88153
# [366]	validation_0-auc:0.88153
# [367]	validation_0-auc:0.88154
# [368]	validation_0-auc:0.88154
# [369]	validation_0-auc:0.88154
# [370]	validation_0-auc:0.88155
# [371]	validation_0-auc:0.88155
# [372]	validation_0-auc:0.88155
# [373]	validation_0-auc:0.88155
# [374]	validation_0-auc:0.88155
# [375]	validation_0-auc:0.88155
# [376]	validation_0-auc:0.88155
# [377]	validation_0-auc:0.88155
# [378]	validation_0-auc:0.88156
# [379]	validation_0-auc:0.88156
# [380]	validation_0-auc:0.88156
# [381]	validation_0-auc:0.88156
# [382]	validation_0-auc:0.88156
# [383]	validation_0-auc:0.88156
# [384]	validation_0-auc:0.88156
# [385]	validation_0-auc:0.88156
# [386]	validation_0-auc:0.88156
# [387]	validation_0-auc:0.88157
# [388]	validation_0-auc:0.88158
# [389]	validation_0-auc:0.88158
# [390]	validation_0-auc:0.88158
# [391]	validation_0-auc:0.88159
# [392]	validation_0-auc:0.88159
# [393]	validation_0-auc:0.88159
# [394]	validation_0-auc:0.88159
# [395]	validation_0-auc:0.88159
# [396]	validation_0-auc:0.88159
# [397]	validation_0-auc:0.88159
# [398]	validation_0-auc:0.88159
# [399]	validation_0-auc:0.88159
# [400]	validation_0-auc:0.88160
# [401]	validation_0-auc:0.88160
# [402]	validation_0-auc:0.88160
# [403]	validation_0-auc:0.88160
# [404]	validation_0-auc:0.88161
# [405]	validation_0-auc:0.88161
# [406]	validation_0-auc:0.88161
# [407]	validation_0-auc:0.88161
# [408]	validation_0-auc:0.88161
# [409]	validation_0-auc:0.88160
# [410]	validation_0-auc:0.88160
# [411]	validation_0-auc:0.88160
# [412]	validation_0-auc:0.88161
# [413]	validation_0-auc:0.88161
# [414]	validation_0-auc:0.88161
# [415]	validation_0-auc:0.88161
# [416]	validation_0-auc:0.88162
# [417]	validation_0-auc:0.88162
# [418]	validation_0-auc:0.88163
# [419]	validation_0-auc:0.88163
# [420]	validation_0-auc:0.88164
# [421]	validation_0-auc:0.88164
# [422]	validation_0-auc:0.88163
# [423]	validation_0-auc:0.88163
# [424]	validation_0-auc:0.88163
# [425]	validation_0-auc:0.88164
# [426]	validation_0-auc:0.88164
# [427]	validation_0-auc:0.88164
# [428]	validation_0-auc:0.88164
# [429]	validation_0-auc:0.88164
# [430]	validation_0-auc:0.88165
# [431]	validation_0-auc:0.88165
# [432]	validation_0-auc:0.88165
# [433]	validation_0-auc:0.88165
# [434]	validation_0-auc:0.88165
# [435]	validation_0-auc:0.88165
# [436]	validation_0-auc:0.88166
# [437]	validation_0-auc:0.88166
# [438]	validation_0-auc:0.88167
# [439]	validation_0-auc:0.88167
# [440]	validation_0-auc:0.88167
# [441]	validation_0-auc:0.88167
# [442]	validation_0-auc:0.88167
# [443]	validation_0-auc:0.88168
# [444]	validation_0-auc:0.88168
# [445]	validation_0-auc:0.88168
# [446]	validation_0-auc:0.88169
# [447]	validation_0-auc:0.88169
# [448]	validation_0-auc:0.88169
# [449]	validation_0-auc:0.88170
# [450]	validation_0-auc:0.88170
# [451]	validation_0-auc:0.88170
# [452]	validation_0-auc:0.88170
# [453]	validation_0-auc:0.88170
# [454]	validation_0-auc:0.88170
# [455]	validation_0-auc:0.88170
# [456]	validation_0-auc:0.88170
# [457]	validation_0-auc:0.88171
# [458]	validation_0-auc:0.88171
# [459]	validation_0-auc:0.88171
# [460]	validation_0-auc:0.88171
# [461]	validation_0-auc:0.88171
# [462]	validation_0-auc:0.88171
# [463]	validation_0-auc:0.88172
# [464]	validation_0-auc:0.88172
# [465]	validation_0-auc:0.88172
# [466]	validation_0-auc:0.88173
# [467]	validation_0-auc:0.88173
# [468]	validation_0-auc:0.88173
# [469]	validation_0-auc:0.88174
# [470]	validation_0-auc:0.88174
# [471]	validation_0-auc:0.88175
# [472]	validation_0-auc:0.88175
# [473]	validation_0-auc:0.88174
# [474]	validation_0-auc:0.88175
# [475]	validation_0-auc:0.88175
# [476]	validation_0-auc:0.88175
# [477]	validation_0-auc:0.88175
# [478]	validation_0-auc:0.88175
# [479]	validation_0-auc:0.88175
# [480]	validation_0-auc:0.88175
# [481]	validation_0-auc:0.88175
# [482]	validation_0-auc:0.88175
# [483]	validation_0-auc:0.88174
# [484]	validation_0-auc:0.88175
# [485]	validation_0-auc:0.88175
# [486]	validation_0-auc:0.88175
# [487]	validation_0-auc:0.88175
# [488]	validation_0-auc:0.88175
# [489]	validation_0-auc:0.88175
# [490]	validation_0-auc:0.88175
# [491]	validation_0-auc:0.88175
# [492]	validation_0-auc:0.88175
# [493]	validation_0-auc:0.88176
# [494]	validation_0-auc:0.88176
# [495]	validation_0-auc:0.88176
# [496]	validation_0-auc:0.88176
# [497]	validation_0-auc:0.88176
# [498]	validation_0-auc:0.88176
# [499]	validation_0-auc:0.88177
# [500]	validation_0-auc:0.88177
# [501]	validation_0-auc:0.88177
# [502]	validation_0-auc:0.88177
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.527109065831463, early_stopping_rounds=20,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.11264881448753765,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=7, missing=nan, monotone_constraints=None,
#               n_estimators=503, n_jobs=-1, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
pred = best_Xgb.predict(x_val)
pred_proba = best_Xgb.predict_proba(x_val)[:,1]
get_clf_eval(y_val,pred,pred_proba)
# Out:
# 정확도: 0.7214
# 정밀도: 0.2983
# 재현율: 0.9356
# F1: 0.4524
# AUC: 0.8818
# AUC2 : 0.8135

# %%
a=best_Xgb.predict_proba(target)[:,1]

# %%
submit = pd.read_csv("./playground-series-s4e7/sample_submission.csv")
pred = a 
submit["Response"] = pred
submit.to_csv("submission_XGB2.csv", index=False)
submit.head()
# Out:
#          id  Response
# 0  11504798     0.035
# 1  11504799     0.885
# 2  11504800     0.712
# 3  11504801     0.001
# 4  11504802     0.412
